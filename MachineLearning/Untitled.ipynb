# %%
import tabula
import pandas as pd
import os

# %%
WDIR = '../../Downloads'

# %%
res = [i for i in os.listdir(WDIR) if i.startswith("Mai")][0]
res
# Out:
# 'Maild76bf445-e5c4-4c2e-9437-263e849618a6.pdf'

# %%
tabula.read_pdf(WDIR + '/'+res)[0]
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.
#    Sıra\rNo  Şube  Müşteri No  \
# 0         1   479    41618763
# 1         2   479    41618763
# 2         3   479    41618763
# 3         4   479    41618763
#
#                                       Müşteri Unvanı   GB No   GB Tarihi  \
# 0  SİNERJİK SİSTEMLER\rGÜVENLİK VE BİLİŞİM\rÇÖZÜM...  340431  07/12/2018
# 1  SİNERJİK SİSTEMLER\rGÜVENLİK VE BİLİŞİM\rÇÖZÜM...   82172  26/03/2019
# 2  SİNERJİK SİSTEMLER\rGÜVENLİK VE BİLİŞİM\rÇÖZÜM...   21237  29/04/2019
# 3  SİNERJİK SİSTEMLER\rGÜVENLİK VE BİLİŞİM\rÇÖZÜM...  105104  08/05/2019
#
#         Referans GB Tutarı GB\rDvz Taahhüt\rVadesi  Açık İhracat\rTutarı  \
# 0  9904792377296    625,00     EUR      07/06/2019                   NaN
# 1  9904792377292    485,00     EUR      23/09/2019                   NaN
# 2  9904792377294  1.670,00     EUR      28/10/2019                   NaN
# 3  9904792377295    675,00     EUR      04/11/2019                   NaN
# ...

# %%
res = [i for i in os.listdir(WDIR) if i.startswith("hesap")][0]
res
# Out:
# 'hesaphareketi-01.pdf'

# %%
tabula.read_pdf(WDIR+ '/'+res,multiple_tables=False,pages=1)[0]
# Out:
#          Tarih                              Açıklama İşlem Tutarı    Bakiye  \
# 0   08.01.2016                                                NaN       NaN
# 1          NaN                               2015 YILI 2. YARIYIL       NaN
# 2          NaN                               HESAP İŞLETİM ÜCRETİ       NaN
# 3          NaN                                             -13,00    147,32
# 4   15.01.2016  INT DÖVİZ ALIŞ 6297811 2016-01-15-16.37.19.207...  9.000,32
# 5          NaN                                    INT DÖVİZ SATIŞ       NaN
# 6   03.02.2016                        9088625 - 6297811 -2.010,00  6.990,32
# 7          NaN                                        EUR:3.20890       NaN
# 8          NaN                                    INT DÖVİZ SATIŞ       NaN
# 9   03.02.2016                          9088625 - 6297811 -491,04  6.499,28
# 10         NaN                                        EUR:3.20750       NaN
# ...
