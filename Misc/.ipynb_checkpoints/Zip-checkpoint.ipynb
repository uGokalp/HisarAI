# %% [markdown]
# # File Handling

# %% [markdown]
# Modes of opening files. By default "r" is assumed.
#
# - r: Opens the file in read-only mode.
# - w: Opens in write-only mode. The pointer is placed at the beginning of the file and this will overwrite any existing file with the same name. It will create a new file if one with the same name doesn't exist.

# %% [markdown]
# Example lets create a txt file.

# %%
with open("file.txt",'w') as f:
    f.write("Hello World!")

# %% [markdown]
# Lets try reading it!

# %%
with open("file.txt",'r') as f:
    print(f.read())
# Out:
# Hello World!

# %% [markdown]
# # Reading CSV

# %%
import pandas
pandas.read_csv("iris.csv")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import csv
z=[]
with open("iris.csv") as iris:
    header = iris.readline().strip().split(',')
    data = csv.DictReader(iris,fieldnames=header, delimiter=',')
    for row in data:
        z.append(row)

# %%
# Out:
# 'excel'

# %% [markdown]
# # Reading JSON

# %% [markdown]
# # Downloading files

# %%
import requests
import matplotlib.pyplot as plt
from PIL import Image

# %%
link = 'https://i.insider.com/5df126b679d7570ad2044f3e?width=1100&format=jpeg&auto=webp'

# %%
r = requests.get(link) # Requesting the data
cont = r.content # accesing the data

# %%
with open("image.png",'wb') as f:
    f.write(cont)
image = Image.open("image.png")

plt.imshow(image)

# %% [markdown]
# # Working with zip files

# %%
from zipfile import ZipFile

# %% [markdown]
# Lets zip the dog picture from above.
#
# We will use the ```with``` context manager now with ZipFile

# %%
with ZipFile("Myzip.zip",'w') as z:
    z.write("image.png")
! ls
# Out:
# Myzip.zip Zip.ipynb file.txt  image.png

# %%
with ZipFile("Myzip.zip") as z:
    z.extractall()
